# %%
from selenium import webdriver
import bs4
import re
import pandas as pd
import time
from IPython.core.display import HTML

# %%
#open chrome driver
path=r'C:\Users\atphor\Downloads\chromedriver'
driver = webdriver.Chrome(executable_path=path)

driver.get('https://shopee.co.th/')
# Out:
# C:\Users\atpho\AppData\Local\Temp\ipykernel_19516\2035735255.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=path)

# %%
#input data
i=input ('input 1-12 :')
name='00'+i
print('name excel :',name)
head =round(int(i)/2)
if int(i) <= 1:
    head = 1
index = i

if int(index) % 2 == 0:
    index = 2
else:
    index = 1

#input number page
current_url=driver.current_url  
number_page = input('How much data do you want? (1 page = 60 data) :')
number_page = int(number_page)
# Out:
# input 1-12 :1
# name excel : 001
# How much data do you want? (1 page = 60 data) :1

# %%
#close popup
thai_button = driver.find_element("xpath",'/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
thai_button.click()

# %%
close_button = driver.execute_script('return document.querySelector("shopee-banner-popup-stateful").shadowRoot.querySelector("div.shopee-popup__close-btn")')
close_button.click()

type_url='/html/body/div[1]/div/div[2]/div/div/div[3]/div[2]/div[1]/div/div/div[2]/div/div[1]/ul/li['+str(head)+']/div/a['+str(index)+']/div/div[1]/div'

Types_button = driver.find_element("xpath",type_url)
#Types_button = driver.find_element("class",'n-CE6j _8YHYKq')
Types_button.click()
time.sleep(5)

Best_sales = driver.find_element("xpath",'/html/body/div[1]/div/div[2]/div/div[1]/div[4]/div[2]/div/div[1]/div[1]/div[3]')
Best_sales.click()

# %%
#zoom out and scraping data
driver.execute_script('document.body.style.zoom="10%"')
time.sleep(10)
data = driver.page_source

soup = bs4.BeautifulSoup(data)

#list all product data
all_product =soup.find_all('div',{'class':"_1yN94N WoKSjC _2KkMCe"})

all_product_list = []
for product in all_product:
    all_product_list.append(product.text)

all_price =soup.find_all('div',{'class':"cbl0HO MUmBjS"})

all_price_list = []
for product in all_price:
    all_price_list.append(product.text)

all_sell =soup.find_all('div',{'class':'x+3B8m wOebCz'})

all_sell_list = []
for product in all_sell:
    all_sell_list.append(product.text)


#removing symbol
all_sell_list =re.findall(r'[\d\.\d]+',str(all_sell_list))#ทำให้ลิสไม่มีตัวหนังสือหรือสัญลักษณ์

#make product dataframe
all_data = pd.DataFrame({
    'Product Name': all_product_list,
    'Price': all_price_list,
    'sold(kpcs./Mouth)': all_sell_list
})

#list url
all_pic =soup.find_all('div',{'class':'usRW1x S8FTqJ'})

all_pic = soup.find_all('img',src=True)
all_pic=all_pic
print('Number of Images: ', len(all_pic))

# select src tag
image_src = [x['src'] for x in all_pic]

#sel only pic
image_src = [x for x in image_src if 61 < len(x)]

#make dataframe
df =pd.DataFrame(image_src,columns=['img'])[0:60]

#sel product
img = image_src[0:60]

df['img'] = img
df = pd.concat([df,all_data],axis=1)

# Converting links to html tags
def path_to_image_html(path):
    return '<img src="'+ path + '" width="60" >'

# Rendering the dataframe as HTML table
df.to_html(escape=False, formatters=dict(img=path_to_image_html))

# Rendering the images in the dataframe using the HTML method.
HTML(df.to_html(escape=False,formatters=dict(img=path_to_image_html)))
# Out:
# Number of Images:  138
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>img</th>
#       <th>Product Name</th>
#       <th>Price</th>
#       <th>sold(kpcs./Mouth)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://cf.shopee.co.th/file/8c4bb17e61620f56b013768ca09969cd_tn" width="60" ></td>
#       <td>[5บ. กดได้ 3 ชิ้น ]🔥[พร้อมส่ง] Munafie พร้อมส่งจากไทยBoxerชาย ผ้านิ่มใส่สบายไม่อึดอัดไม่มีถุงซิป MW#00000</td>
#       <td>฿12</td>
#       <td>48.5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://cf.shopee.co.th/file/th-11134207-23020-mrgewval8pnva0_tn" width="60" ></td>
#       <td>（แพ็คเกจส่วนบุคคล）👍ส่งเร็ว 1-2 วัน🌈 Munafie พร้อมส่งจากไทยBoxerชาย ผ้านิ่มใส่สบายไม่อึดอัดไม่มีถุงซิป</td>
#       <td>฿10</td>
#       <td>13.1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://cf.shopee.co.th/file/b66b9ed2c5a695bbe099b72085cebb2d_tn" width="60" ></td>
#       <td>กางเกงในผู้ชายBoocon เนื้อผ้านุ่มใส่สบาย ขอบไม่ระคายเคือง เนื้อผ้าระบายอากาศได้ดี</td>
#       <td>฿28 - ฿31</td>
#       <td>12.3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="https://cf.shopee.co.th/file/856c846ef0e81c4c13ce2802fb7b4ff0_tn" width="60" ></td>
#       <td>⚡️F09⚡️ซื้อ10แถม1 กางเกงบ๊อกเซอร์ Boxer S-2XL*ราคาต่อชิ้น*</td>
#       <td>฿25 - ฿55</td>
#       <td>11.1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="https://cf.shopee.co.th/file/26fb147111defcc31f56980bd7e36347_tn" width="60" ></td>
#       <td>เสื้อยืดสีพื้น คอกลม เกรดพรีเมี่ยม❤️ ใส่สบาย ไม่หด ไม่ต้องรีด ราคาส่ง มีเก็บเงินปลายทาง ❤️ (สินค้าพร้อมจัดส่งทุกวันค่ะ)</td>
#       <td>฿37 - ฿52</td>
#       <td>10.5</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="https://cf.shopee.co.th/file/c4a09fa9bbc55625ca4fbda2e0758a54_tn" width="60" ></td>
#       <td>TOP1 กางเกงในชาย MUNAFIE เนื้อผ้านุ่ม มีซองใส่ทุกตัว รุ่นขาเว้า</td>
#       <td>฿12 - ฿14</td>
#       <td>10.4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="https://cf.shopee.co.th/file/a75f7fa8ca0ca1302cb72aa981c4acd8_tn" width="60" ></td>
#       <td>MW036กางเกงในชาย ขาเว้า MUNAFIE เนื้อผ้านิ่มบางเบาไม่มีถุงซิป</td>
#       <td>฿11</td>
#       <td>8.7</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="https://cf.shopee.co.th/file/th-11134207-23020-f1scyufiponvd3_tn" width="60" ></td>
#       <td>กางเกงในผู้ชาย ผ้านิ่ม ใส่สบาย ขอบไม่เจ็บ มี 8สีให้เลือก</td>
#       <td>฿28</td>
#       <td>6.8</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="https://cf.shopee.co.th/file/60cc0b26eec9096fdd851f194cdec7c3_tn" width="60" ></td>
#       <td>【พร้อมส่ง】Nk กางเกงชั้นในผ้าฝ้ายเอวยางยืดพิมพ์ลายตัวอักษรแฟชั่นผู้ชาย</td>
#       <td>฿29</td>
#       <td>6.4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="https://cf.shopee.co.th/file/44331c7da84e66fe8c913174fe3eb722_tn" width="60" ></td>
#       <td>กางเกงชั้นในชาย บ็อกเซอร์MUNAFIE  NK-19 Boxer บ็อกเซอร์ชาย ไร้รอยต่อ ขาเหลี่ยม สินค้าพร้อมส่ง</td>
#       <td>฿11</td>
#       <td>6.1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="https://cf.shopee.co.th/file/0c7006cfd4a3ecaf695d151f596393e2_tn" width="60" ></td>
#       <td>กางเกงในชายck 🔥Cafee Koaia🔥ทรงboxer ผ้าcotton เกรดพรีเมี่ยม ผ้าบางเบา นุ่มพิเศษ</td>
#       <td>฿38</td>
#       <td>5.7</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="https://cf.shopee.co.th/file/21f0d63ee8e21583433435f81bc02b7a_tn" width="60" ></td>
#       <td>#071 พร้อมส่ง‼️Boxerชาย แบรนด์Munafie ขอบตัดสี ผ้านิ่มใส่สบาย ไม่อึดอัด |มีซองทุกตัว #Boxer N</td>
#       <td>฿13</td>
#       <td>5.6</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="https://cf.shopee.co.th/file/e5bed13e0e26e354559c9a9f06c9e2e4_tn" width="60" ></td>
#       <td>TC กางเกงในผู้ชาย เนื้อผ้านิ่ม ใส่สบาย รุ่นA81</td>
#       <td>฿20</td>
#       <td>5.5</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="https://cf.shopee.co.th/file/55dda58c54dbb0179ca3666358af9ddc_tn" width="60" ></td>
#       <td>ชุดชั้นในชาย บ็อกเซอร์MUNAFIE  NK-18 กางเกงในชาย เยื้อผ้ายืด ขาเว้า เก็บทรงได้ดี</td>
#       <td>฿11</td>
#       <td>4.9</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="https://cf.shopee.co.th/file/6644534703c3de87e14ee6698ee1a7c8_tn" width="60" ></td>
#       <td>Boxerชาย กางเกงในชาย MUNAFIE ผ้านิ่มใส่สบาย ไม่อึดอัด มีซองใส่ทุกตัว</td>
#       <td>฿12 - ฿14</td>
#       <td>4.7</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="https://cf.shopee.co.th/file/sg-11134201-22120-fc334pt96zkv6f_tn" width="60" ></td>
#       <td>[ลด10% โค้ด MAR50MA] โฉมใหม่กระดุมสีเดียวกับเสื้อ S1: เสื้อเชิ้ตเกาหลี แขนสั้น สีพื้น มีไซซ์ M L XL XXL ชาย/หญิง</td>
#       <td>฿119 - ฿125</td>
#       <td>4.2</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="https://cf.shopee.co.th/file/90cd62cb7afeee4cade4cb1bd753c2aa_tn" width="60" ></td>
#       <td>[พร้อมส่ง]ถูกมาก🌈ถูก สวย ดี มีมาตรฐาน 🔥เสื้อคนงาน 🟦คอปก ฟรีไซส์</td>
#       <td>฿44</td>
#       <td>4.1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="https://cf.shopee.co.th/file/th-11134207-23030-mnlvps57faovbc_tn" width="60" ></td>
#       <td>กางเกงขาสั้น BRNG BRNG โลโก้ปัก ถูกๆ🔥ลดแรง🔥มีกระเป๋า 2 ข้าง</td>
#       <td>฿48 - ฿55</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="https://cf.shopee.co.th/file/5505c45648e3569411130ad5ba664462_tn" width="60" ></td>
#       <td>Sale‼️ 🔥กางเกงในชาย MUNAFIE เนื้อผ้านุ่ม มีซองทุกตัว เก็บปลายทางได้ #เว้าพื้น（8825-1 (ใส่โค้ด SSPV7K ลดเพิ่ม 25%)</td>
#       <td>฿12</td>
#       <td>3.9</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="https://cf.shopee.co.th/file/790cfe43c58748e67d31a543adf84c6b_tn" width="60" ></td>
#       <td>Sale‼️ 🔥พร้อมส่ง‼️Boxerชาย แบรนด์Munafie ผ้านิ่มใส่สบาย ไม่อึดอัด |มีซองทุกตัว (8825)</td>
#       <td>฿13</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td><img src="https://cf.shopee.co.th/file/3f4b5d60c268f31f0cf12e494cc979f8_tn" width="60" ></td>
#       <td>Bradeni กางเกงในชาย เนื้อผ้านิ่ม แบนด์ญี่ปุ่น ราคาโปรโมชั่น 🔥🔥 (ใส่โค้ด SSPRHR ลดเพิ่ม 25%)</td>
#       <td>฿35</td>
#       <td>3.5</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td><img src="https://cf.shopee.co.th/file/sg-11134201-22120-cnd747264ykv20_tn" width="60" ></td>
#       <td>⚡️F03-2⚡️กางเกงขาสั้นผ้าสำลี S-2XL 14สี#รับประกันคุณภาพ</td>
#       <td>฿79 - ฿89</td>
#       <td>3.4</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td><img src="https://cf.shopee.co.th/file/e6a93d24ff8368f3c876af2ebbb1f392_tn" width="60" ></td>
#       <td>⚡️F30.⚡️ลดล้างสต็อก กางเกงในชายขอบหุ้ม</td>
#       <td>฿9 - ฿19</td>
#       <td>3.3</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td><img src="https://cf.shopee.co.th/file/th-11134201-23020-vch96pbox3nv5a_tn" width="60" ></td>
#       <td>Yuedpao ยอดขาย No.1 รับประกันไม่ย้วย 2 ปี ผ้านุ่ม เสื้อยืดเปล่า เสื้อยืดสีพื้น เสื้อยืดคอกลม_สีขาว</td>
#       <td>฿100 - ฿120</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td><img src="https://cf.shopee.co.th/file/a2d0a3a2eed44d3b42f3458e4903b472_tn" width="60" ></td>
#       <td>⚡️⚡️บ๊อกเซอร์ สีพื้น สีไม่ตก เนื้อผ้านุ่มมาก ใส่สบาย คุณภาพดี</td>
#       <td>฿48 - ฿58</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td><img src="https://cf.shopee.co.th/file/f6d024519221986a4590d648f16e91c4_tn" width="60" ></td>
#       <td>🔥[พร้อมส่ง] Munafie พร้อมส่งจากไทย Boxerชาย ผ้านิ่มใส่สบาย ไม่อึดอัด ไม่มีถุงซิป MW#00000</td>
#       <td>฿12</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td><img src="https://cf.shopee.co.th/file/sg-11134201-22100-xpvg3s07pgivfc_tn" width="60" ></td>
#       <td>บ๊อกเซอร์ สีพื้น 🔥ลายใหม่🔥 L-2XL แบร์น UOKIN เนื้อผ้านิ่ม ใส่สบาย เกรดพรีเมี่ยม B01</td>
#       <td>฿45</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td><img src="https://cf.shopee.co.th/file/ded5b10f2fbb8bc04b4f4f913a0c09eb_tn" width="60" ></td>
#       <td>TS MEN เสื้อยืดคอกลมแขนสั้น เสื้อยืดผู้ชาย เสื้อยืดสีล้วน（สีดำ สีขาว）รุ่น 0019</td>
#       <td>฿50 - ฿55</td>
#       <td>3.2</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td><img s

# %%
#name excel
def hi_var(var_name):
    globals()[var_name]=df  
hi_var(name)
df.to_excel(name+'.xlsx')
